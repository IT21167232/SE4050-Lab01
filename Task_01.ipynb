# %%
from __future__ import division, print_function, unicode_literals

# %%
import numpy as np

# %% [markdown]
# Create a random 4x4 array from an exponential distribution.

# %%
exponential_array = np.random.exponential(scale=1.0, size=(4,4))

# %%
print(exponential_array)
# Out:
# [[4.1516504  0.54237908 3.83496427 0.01700445]
#  [0.79271965 2.65064043 2.65228213 1.63861466]
#  [0.15957298 2.37081733 1.74299647 0.45945559]
#  [2.50773475 6.38754893 0.57353431 0.19188045]]

# %% [markdown]
# impport matplotlib.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Create a random 100000x1 array from the same exponential distribution and visualize the distribution histogram along with uniform and normal distributions.

# %%
exponential_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.uniform(low=-2.5, high=2.5, size=100000)
normal_data = np.random.normal(loc=0.0,scale=1.0,size=100000)

# %%
plt.hist(exponential_data, density=True, bins=100, histtype="step", color="red", label="Exponential")
plt.hist(uniform_data, density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=100, histtype="step", color="green", label="Normal")
# Out:
# (array([2.26057322e-04, 1.13028661e-04, 1.13028661e-04, 2.26057322e-04,
#         2.26057322e-04, 3.39085984e-04, 6.78171967e-04, 6.78171967e-04,
#         1.24331527e-03, 1.13028661e-03, 2.14754456e-03, 2.37360189e-03,
#         4.63417511e-03, 4.86023243e-03, 5.53840440e-03, 6.89474833e-03,
#         7.79897762e-03, 1.07377228e-02, 1.35634393e-02, 1.98930444e-02,
#         2.28317896e-02, 2.78050507e-02, 3.45867703e-02, 4.28378626e-02,
#         4.86023243e-02, 6.22787923e-02, 7.01907986e-02, 8.54496679e-02,
#         9.60743620e-02, 1.14611062e-01, 1.30095989e-01, 1.53832008e-01,
#         1.67056361e-01, 1.84462775e-01, 2.07633651e-01, 2.38829561e-01,
#         2.45046138e-01, 2.77485363e-01, 2.90483659e-01, 3.13089392e-01,
#         3.31739121e-01, 3.51971251e-01, 3.64404404e-01, 3.69151608e-01,
#         3.86558021e-01, 3.92887626e-01, 4.08711639e-01, 3.89835853e-01,
#         3.89157681e-01, 3.83845333e-01, 3.79098130e-01, 3.76724528e-01,
# ...

# %%
plt.axis([-2.5, 10, 0, 1.5])
plt.legend(loc="upper right")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 3D plot using Matplotlib, you can use the Axes3D module.

# %% [markdown]
# Generate data

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# %% [markdown]
# Create a 3D plot.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# %% [markdown]
# Set labels and title.

# %%
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('3D plot of Z = X^2 + Y^2')
# Out:
# Text(0.5, 0.92, '3D plot of Z = X^2 + Y^2')

# %%
plt.show()

# %% [markdown]
# 4.Calculate the pearson standard coefficient and spearman rank correlation.

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
from scipy.stats import pearsonr, spearmanr

# %%
import pandas as pd

df_url = pd.read_csv("/content/Pokemon.csv", index_col=0,encoding="latin")
df_url.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# Assuming df_url is the DataFrame you want to use

# %%
import pandas as pd


data = df_url[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
print(data.head())
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1  45      49       49       65       65     45
# 2  60      62       63       80       80     60
# 3  80      82       83      100      100     80
# 4  39      52       43       60       50     65
# 5  58      64       58       80       65     80

# %%
pearson_corr = data.corr(method='pearson')
spearman_corr = data.corr(method='spearman')

# %%
def plot_heatmap(corr_matrix, title):
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
    plt.title(title)
    plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', ax=axes[0])
axes[0].set_title('Pearson Correlation')

sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', ax=axes[1])
axes[1].set_title('Spearman Correlation')

plt.show()
